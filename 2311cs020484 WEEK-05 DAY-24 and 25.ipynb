# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
cars=pd.read_csv('Cars.csv')
cars
# Out:
#      HP        MPG  VOL          SP         WT
# 0    49  53.700681   89  104.185353  28.762059
# 1    55  50.013401   92  105.461264  30.466833
# 2    55  50.013401   92  105.461264  30.193597
# 3    70  45.696322   92  113.461264  30.632114
# 4    53  50.504232   92  104.461264  29.889149
# ..  ...        ...  ...         ...        ...
# 76  322  36.900000   50  169.598513  16.132947
# 77  238  19.197888  115  150.576579  37.923113
# 78  263  34.000000   50  151.598513  15.769625
# 79  295  19.833733  119  167.944460  39.423099
# 80  236  12.101263  107  139.840817  34.948615
#
# [81 rows x 5 columns]

# %%
cars.head()
# Out:
#    HP        MPG  VOL          SP         WT
# 0  49  53.700681   89  104.185353  28.762059
# 1  55  50.013401   92  105.461264  30.466833
# 2  55  50.013401   92  105.461264  30.193597
# 3  70  45.696322   92  113.461264  30.632114
# 4  53  50.504232   92  104.461264  29.889149

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   HP      81 non-null     int64
#  1   MPG     81 non-null     float64
#  2   VOL     81 non-null     int64
#  3   SP      81 non-null     float64
#  4   WT      81 non-null     float64
# dtypes: float64(3), int64(2)
# memory usage: 3.3 KB

# %%
cars.tail()
# Out:
#      HP        MPG  VOL          SP         WT
# 76  322  36.900000   50  169.598513  16.132947
# 77  238  19.197888  115  150.576579  37.923113
# 78  263  34.000000   50  151.598513  15.769625
# 79  295  19.833733  119  167.944460  39.423099
# 80  236  12.101263  107  139.840817  34.948615

# %%
cars.isna().sum()
# Out:
# HP     0
# MPG    0
# VOL    0
# SP     0
# WT     0
# dtype: int64

# %%
cars.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 76    False
# 77    False
# 78    False
# 79    False
# 80    False
# Length: 81, dtype: bool

# %%
cars.duplicated
# Out:
# <bound method DataFrame.duplicated of      HP        MPG  VOL          SP         WT
# 0    49  53.700681   89  104.185353  28.762059
# 1    55  50.013401   92  105.461264  30.466833
# 2    55  50.013401   92  105.461264  30.193597
# 3    70  45.696322   92  113.461264  30.632114
# 4    53  50.504232   92  104.461264  29.889149
# ..  ...        ...  ...         ...        ...
# 76  322  36.900000   50  169.598513  16.132947
# 77  238  19.197888  115  150.576579  37.923113
# 78  263  34.000000   50  151.598513  15.769625
# 79  295  19.833733  119  167.944460  39.423099
# 80  236  12.101263  107  139.840817  34.948615
#
# [81 rows x 5 columns]>

# %%
cars.head()
# Out:
#    HP        MPG  VOL          SP         WT
# 0  49  53.700681   89  104.185353  28.762059
# 1  55  50.013401   92  105.461264  30.466833
# 2  55  50.013401   92  105.461264  30.193597
# 3  70  45.696322   92  113.461264  30.632114
# 4  53  50.504232   92  104.461264  29.889149

# %% [markdown]
# # EDA

# %% [raw]
# dist plot       -->   distribution plot(shows the relationship b/w density and attribute provided)
# violin plot     -->
# box plot        -->   plotting is done in the form of boxes
# scatter plot    -->   BI-VARIENT analysis(2 values required for the scattering case)

# %%
sns.distplot(cars['HP'])
plt.show()

# %%
sns.distplot(cars['MPG'])
plt.show()

# %%
sns.distplot(cars['VOL'])
plt.show()

# %%
sns.distplot(cars['SP'])
plt.show()

# %%
sns.distplot(cars['WT'])
plt.show()

# %%
sns.boxplot(cars['HP'])
# Out:
# <Axes: >

# %%
sns.boxplot(cars['MPG'])
# Out:
# <Axes: >

# %%
sns.boxplot(cars['VOL'])
# Out:
# <Axes: >

# %%
sns.boxplot(cars['SP'])
# Out:
# <Axes: >

# %%
sns.boxplot(cars['WT'])
# Out:
# <Axes: >

# %%
sns.violinplot(cars['HP'])
# Out:
# <Axes: >

# %%
sns.violinplot(cars['MPG'])
# Out:
# <Axes: >

# %%
sns.violinplot(cars['VOL'])
# Out:
# <Axes: >

# %%
sns.violinplot(cars['SP'])
# Out:
# <Axes: >

# %%
sns.violinplot(cars['WT'])
# Out:
# <Axes: >

# %%
sns.scatterplot(cars['HP'])
# Out:
# <Axes: ylabel='HP'>

# %%
sns.scatterplot(cars['MPG'])
# Out:
# <Axes: ylabel='MPG'>

# %%
sns.scatterplot(cars['VOL'])
# Out:
# <Axes: ylabel='VOL'>

# %%
sns.scatterplot(cars['SP'])
# Out:
# <Axes: ylabel='SP'>

# %%
sns.scatterplot(cars['WT'])
# Out:
# <Axes: ylabel='WT'>

# %%
sns.scatterplot(x=cars['HP'],y=cars['MPG'])
# Out:
# <Axes: xlabel='HP', ylabel='MPG'>

# %%
sns.scatterplot(x=cars['VOL'],y=cars['SP'])
# Out:
# <Axes: xlabel='VOL', ylabel='SP'>

# %%
sns.scatterplot(x=cars['VOL'],y=cars['WT'])
# Out:
# <Axes: xlabel='VOL', ylabel='WT'>

# %%
sns.scatterplot(x=cars['HP'],y=cars['MPG'])
# Out:
# <Axes: xlabel='HP', ylabel='MPG'>

# %%
sns.scatterplot(x=cars['MPG'],y=cars['WT'])
# Out:
# <Axes: xlabel='MPG', ylabel='WT'>

# %%
sns.scatterplot(x=cars['SP'],y=cars['VOL'])
# Out:
# <Axes: xlabel='SP', ylabel='VOL'>

# %%
sns.scatterplot(x=cars['VOL'],y=cars['MPG'])
# Out:
# <Axes: xlabel='VOL', ylabel='MPG'>

# %%
sns.heatmap(cars)
# Out:
# <Axes: >

# %%
sns.heatmap(cars.corr(),cmap='Reds',annot=True)
plt.show() #shows the values with respect to all the variables

# %%
sns.heatmap(cars.corr(),cmap='Greens',annot=True)
plt.show() #shows the values with respect to all the variables

# %%
sns.heatmap(cars.corr(),cmap='Blues',annot=True)
plt.show() #shows the values with respect to all the variables

# %%
sns.scatterplot(cars)
# Out:
# <Axes: >
